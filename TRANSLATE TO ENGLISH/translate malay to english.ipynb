# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
#search term

query = "('Celcom murah OR Celcom laju OR Celcom slow OR Celcom bagus OR Celcom mahal OR Celcom  tiada line' )  until:2023-03-31 since:2019-03-31"

tweets = []
limit = 150


for tweet in sntwitter.TwitterHashtagScraper(query).get_items():
    
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.date, tweet.url, tweet.user.username, tweet.sourceLabel, tweet.user.location, tweet.content])
        
df = pd.DataFrame(tweets, columns=['Date', 'TweetURL','User', 'Source', 'Location', 'Text'])
# Out:
# <ipython-input-46-ef6fd0c4b418>:14: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.date, tweet.url, tweet.user.username, tweet.sourceLabel, tweet.user.location, tweet.content])

# %%
df.shape
# Out:
# (150, 6)

# %%
df.head()
# Out:
#                        Date  \
# 0 2023-03-16 14:12:56+00:00
# 1 2023-03-16 13:11:30+00:00
# 2 2023-03-16 11:42:18+00:00
# 3 2023-03-14 09:39:15+00:00
# 4 2023-03-05 01:27:48+00:00
#
#                                                      TweetURL         User  \
# 0  https://twitter.com/shaanizzle_/status/1636369963345924100  shaanizzle_
# 1  https://twitter.com/florendymph/status/1636354503162359809  florendymph
# 2  https://twitter.com/taecyeon883/status/1636332054764990464  taecyeon883
# 3    https://twitter.com/asmaatina/status/1635576315574374406    asmaatina
# 4      https://twitter.com/zaryl2k/status/1632191144552726531      zaryl2k
#
#                 Source    Location  \
# 0  Twitter for Android         BKI
# 1  Twitter for Android
# 2   Twitter for iPhone
# 3  Twitter for Android  ipoh perak
# 4     Twitter for iPad
#
#                                                                                                                                                     Text
# ...

# %%
# !pip install googletrans==3.1.0a0

# %%
from googletrans import Translator
import pandas as pd
translator = Translator()



df['Translated Text'] = df['Text'].apply(translator.translate,src='ms',dest='en').apply(getattr,args=('text',))

df.head()
# Out:
#                        Date  \
# 0 2023-03-16 14:12:56+00:00
# 1 2023-03-16 13:11:30+00:00
# 2 2023-03-16 11:42:18+00:00
# 3 2023-03-14 09:39:15+00:00
# 4 2023-03-05 01:27:48+00:00
#
#                                                      TweetURL         User  \
# 0  https://twitter.com/shaanizzle_/status/1636369963345924100  shaanizzle_
# 1  https://twitter.com/florendymph/status/1636354503162359809  florendymph
# 2  https://twitter.com/taecyeon883/status/1636332054764990464  taecyeon883
# 3    https://twitter.com/asmaatina/status/1635576315574374406    asmaatina
# 4      https://twitter.com/zaryl2k/status/1632191144552726531      zaryl2k
#
#                 Source    Location  \
# 0  Twitter for Android         BKI
# 1  Twitter for Android
# 2   Twitter for iPhone
# 3  Twitter for Android  ipoh perak
# 4     Twitter for iPad
#
# ...

# %%
df
# Out:
#                          Date  \
# 0   2023-03-16 14:12:56+00:00
# 1   2023-03-16 13:11:30+00:00
# 2   2023-03-16 11:42:18+00:00
# 3   2023-03-14 09:39:15+00:00
# 4   2023-03-05 01:27:48+00:00
# ..                        ...
# 145 2021-05-07 06:32:55+00:00
# 146 2021-05-06 15:29:42+00:00
# 147 2021-05-06 12:54:56+00:00
# 148 2021-05-01 03:57:07+00:00
# 149 2021-04-29 11:47:27+00:00
#
#                                                          TweetURL  \
# 0      https://twitter.com/shaanizzle_/status/1636369963345924100
# 1      https://twitter.com/florendymph/status/1636354503162359809
# 2      https://twitter.com/taecyeon883/status/1636332054764990464
# 3        https://twitter.com/asmaatina/status/1635576315574374406
# 4          https://twitter.com/zaryl2k/status/1632191144552726531
# ..                                                            ...
# 145      https://twitter.com/itsmepaah/status/1390555226260660224
# ...
